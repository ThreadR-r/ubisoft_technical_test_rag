# %% [markdown]
# - Author: Elian Freyermuth
# - Date: 10/12/2023
#
# Summary:
# First, thank you for this technical test. I had the occasion to try different methods as to have good results. I first tried using the Jaccard token based distance to find the similarity between the questions and the article but it didn't give good results. Thus, I have decided to use a custom tokenizer and Embedding layer to process the data, the goal was to take the embeddings of the articles and for each question compare the embedding distance (Minkowski or Cosine similarity). Previously used in two previous projets it worked like a charm, but here it struggled a lot and the questions were not well bounded to the articles.
# <br/><br/>
# As a consequence, I have decided to try pre-trained bigger model such as bert-base-uncased, xlm-roberta-base and xlm-v to get the embeddings, however it doesn't seem to give proper results either.
# I have decided to stop here after long research of understanding what could be the problem. I would be glad to have any advice about this test and my methods.
# <br/><br/>
#
# Thank you again,
# Best regards,
# Elian Freyermuth

# %%
import pandas as pd
from bs4 import BeautifulSoup
# !pip install textdistance
import textdistance as td
import torch

from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# Requirement already satisfied: textdistance in /usr/local/lib/python3.10/dist-packages (4.6.0)

# %% [markdown]
# ## Dataset reading and cleaning

# %%
questions_df = pd.read_csv("./simulated_questions.csv")
questions_df
# Out:
#                                              question
# 0                    How to make an explosive in FC5?
# 1   Are there any news on when AC Jade will be ava...
# 2   Is it possible to continue my progression if I...
# 3   Will Starlink run on a GPU with 2GB RAM? Is th...
# 4   How to report a toxic playing behavior in Mari...
# 5        I have an error BE8A522E. What does it mean?
# 6   I wanted to play HoMM IV after a long break, b...
# 7                     How to sign up for Just Dance+?
# 8   I can't find the Discovery Tour in ACV despite...
# 9   Comment puis-je informer les développeurs d'Ub...
# 10  Est-il possible d'obtenir un Alpha Pack gratui...
# 11  Quelle est la signification des anneaux blancs...
# 12  Comment résoudre le problème "Service Ubisoft ...
# 13  Puis-je changer le nom de famille de mon compte ?
# 14  J'aimerais lancer le jeu dans une fenêtre. Est...
# 15  comment restaurer les pièces perdues dans la "...
# 16      J'obtiens l'erreur 17008. Que dois-je faire ?
# 17               Quelle est l'histoire du jeu du FH ?
# 18  Y a-t-il des défis coopératifs dans Mario + La...
# 19  ¿Es posible jugar Trials Rising con un amigo e...
# 20  ¿Puedo comprar algunos créditos de billetera a...
# 21  ¿Cómo llegar a la campaña de Jack The Ripper e...
# 22  ¿Cuál es la diferencia entre las ediciones "de...
# 23  ¿Cómo desbloquear la misión "Secretos de las p...
# 24  No se puede conectar a los servidores de Ubiso...
# 25  ¿Es posible asociar mis perfiles de Ubisoft y ...
# 26  ¿Es posible modificar la dificultad de Starlin...
# 27  ¿Dónde conseguir las recompensas "Ubi Connect"...

# %%
faq_articles_df = pd.read_csv("./FAQ_articles.csv")
faq_articles_df
# Out:
#     articleID                                              title  \
# 0       74416  Contents of the Assassin's Creed: Syndicate Se...
# 1       97885          Linking your YouTube and Ubisoft accounts
# 2       80266  Unlocking Ubisoft Connect Rewards for legacy g...
# 3       80333                Error code 17008 in Ubisoft Connect
# 4      105788  Decommissioning of online services for older U...
# ..        ...                                                ...
# 95      94241  Upgrading Rainbow Six: Siege from PlayStation ...
# 96      96236                       Checking your NAT type on PC
# 97      97861  Carrying over your Rocksmith+ Closed Beta prog...
# 98      65237  Language options in Assassin's Creed: The Rebe...
# 99      60487        Online Multiplayer Settings in Watch Dogs 2
#
#                                          html_content  \
# 0   <div>The Season Pass offers access to addition...
# 1   <div>To <strong>link</strong> your <a href="ht...
# 2   <div>Some older Ubisoft titles no longer recei...
# 3   If you receive this error, there are a few wor...
# 4   <div>Decommissioning the online services for <...
# ..                                                ...
# 95  <div>\n<div>\n<div>\n<div>In order to <u><a hr...
# 96  <div>The <a href="https://ubisoft.com/help/art...
# 97  The <em>Rocksmith+</em> Closed Beta is a work ...
# 98  <div>Below is a list of supported languages fo...
# 99  Watch Dogs 2 allows you to decide how much of ...
#
#                                                   URL
# 0   https://www.ubisoft.com/help/game/article/titl...
# 1   https://www.ubisoft.com/help/game/article/titl...
# 2   https://www.ubisoft.com/help/game/article/titl...
# 3   https://www.ubisoft.com/help/game/article/titl...
# 4   https://www.ubisoft.com/help/game/article/titl...
# ..                                                ...
# 95  https://www.ubisoft.com/help/game/article/titl...
# 96  https://www.ubisoft.com/help/game/article/titl...
# 97  https://www.ubisoft.com/help/game/article/titl...
# 98  https://www.ubisoft.com/help/game/article/titl...
# 99  https://www.ubisoft.com/help/game/article/titl...
#
# [100 rows x 4 columns]

# %%
def extract_text_from_html(html:str)->str:
    html_example = faq_articles_df["html_content"][0]
    soup = BeautifulSoup(html, "html.parser")
    return soup.get_text().strip()

faq_articles_df["html_content"] = faq_articles_df["html_content"].map(extract_text_from_html) #no need to keep original html

# %% [markdown]
# # Jaccard distance method

# %%
question_test = questions_df.iloc[0]["question"]
print(f"Question: \"{question_test}\"")
distance = lambda html_text_content: td.jaccard(question_test.split(), html_text_content.split())

tmp_df = pd.DataFrame(faq_articles_df["html_content"].copy(deep=True))
tmp_df["score"] = tmp_df["html_content"].map(distance)
tmp_df.sort_values(by="score", ascending=False, inplace=True)
tmp_df.to_csv("./tmp.csv")
print(tmp_df)
# Out:
# Question: "How to make an explosive in FC5?"
#                                          html_content     score
# 60  To delete an Autodance:\n• Highlight the Just ...  0.065217
# 35  At Ubisoft we are committed to providing an in...  0.065217
# 13  At Ubisoft we are committed to providing an in...  0.060000
# 97  The Rocksmith+ Closed Beta is a work in progre...  0.050000
# 84  This error indicates that you have been unable...  0.050000
# ..                                                ...       ...
# 48  セーブデータはクラウドサーバーに保存されます。Nintendo Switch本体／SDカード...  0.000000
# 91  To use photo mode:\n•  Open the in-game menu.\...  0.000000
# 29  Below is a list of the supported languages for...  0.000000
# 2   Some older Ubisoft titles no longer receive pa...  0.000000
# 98  Below is a list of supported languages for Ass...  0.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# To explain my path of research. I started by trying unsupervized learning method by using string similarity distance as it was the easiest.
# Unfortunately as seen previously, the results aren't that great and doesn't lead to the correct answers.
# Therefore it lead me to try using embedding and nearest neighbours.

# %% [markdown]
# # Custom Tokenizer and Embedding Layer

# %%
class CustomTokenizer:
    def __init__(self):
        self.vocab = {}

    def text_cleaner(text:str)->str:
        is_alpha_space_filter = lambda c: str.isalnum(c) or c==" "
        return ''.join(filter(is_alpha_space_filter, text))

    @property
    def vocab_size(self):
        return len(self.vocab)

    def tokenize(self, text):
        tokens = CustomTokenizer.text_cleaner(text).lower().split()  # Replace this with your custom tokenization logic
        return tokens

    def __call__(self, text:str): return self.sentence_to_ids(text)

    def add_vocab_from_sentence(self, sentence):
        tokens = self.tokenize(sentence)
        for token in tokens:
            if token not in self.vocab:
                self.vocab[token] = len(self.vocab)

    def sentence_to_ids(self, sentence):
        return self.__tokens_to_ids(self.tokenize(sentence))

    def __tokens_to_ids(self, tokens):
        return [self.vocab[token] for token in tokens if token in self.vocab]

# %%
custom_tokenizer = CustomTokenizer()
questions_df["question"].map(custom_tokenizer.add_vocab_from_sentence)
faq_articles_df["html_content"].map(custom_tokenizer.add_vocab_from_sentence)
print("Vocabular size:", custom_tokenizer.vocab_size)
# Out:
# Vocabular size: 2166

# %%
embedding = torch.nn.Embedding(tokenizer.vocab_size, 1024)
def embed(text:str):
    tokenized = custom_tokenizer(text)
    if len(tokenized)==0:
        return None
    text_embedded = embedding(torch.tensor(tokenized)).mean(dim=0).cpu().detach().numpy()
    return text_embedded

# %%
faq_articles_df["content_embedding"] = faq_articles_df["html_content"].progress_apply(embed)
faq_articles_df.dropna(subset=["content_embedding"], inplace=True)
faq_articles_df["title_embedding"] = faq_articles_df["title"].progress_apply(embed)
faq_articles_df.dropna(subset=["title_embedding"], inplace=True)
questions_df["embedding"] = questions_df["question"].progress_apply(embed)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 704.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 16508.46it/s]
# 100%|██████████| 28/28 [00:00<00:00, 3192.62it/s]

# %%
question_test_id = 1
question_test = questions_df.iloc[question_test_id]
print(f"Question: \"{question_test['question']}\"")

custom_embedding = embedding(torch.tensor(custom_tokenizer(question_test["question"]))).mean(dim=0).cpu().detach()

cos_sim = torch.nn.CosineSimilarity(dim=0)
def distance(html_text:str):
    with torch.no_grad():
        tokenized = custom_tokenizer(html_text)
        if len(tokenized)==0:
            return -1
        text_embedded = embedding(torch.tensor(tokenized))
        # print("======")
        # print(text_embedded.shape, question_test_embedded.shape)
        # print(text_embedded.mean(dim=0).shape, question_test_embedded.mean(dim=0).shape)
        # print("======")
        similarity = cos_sim(text_embedded.mean(dim=0), custom_embedding).item()
    return similarity

def string_similarity(serie: pd.Series):
    _df_similarity_score = serie.progress_apply(distance)
    # _df_similarity_score.dropna(inplace=True)
    # soft_max = torch.nn.Softmax(dim=0)
    # _df_similarity_score = pd.Series(soft_max(torch.tensor(_df_similarity_score.values)))
    return _df_similarity_score

tmp_df = pd.DataFrame(faq_articles_df[["html_content", "title"]].copy(deep=True))
# tmp_df["score_html_text"] = string_similarity(tmp_df["html_text_content"])
tmp_df["score_title"] = string_similarity("title: " + tmp_df["title"] + "\n content: " + tmp_df["html_content"])

tmp_df.sort_values(by="score_title", ascending=False, inplace=True)
print(tmp_df)
tmp_df.to_csv("./tmp.csv")
# Out:
# Question: "Are there any news on when AC Jade will be available?"
#   0%|          | 0/100 [00:00<?, ?it/s]
#                                          html_content  \
# 70  When DedSec operatives are critically injured,...
# 8   Following the shutdown of Stadia on 18 January...
# 19  This error occurs when Ubisoft Connect PC is u...
# 4   Decommissioning the online services for older ...
# 57  As you progress through Sequence 3, Memory 4 (...
# ..                                                ...
# 90  In Roller Champions, you can customize your av...
# 25  Back in 2017, For Honor made its debut and int...
# 30  In Far Cry 6 you can change the language for t...
# 48  セーブデータはクラウドサーバーに保存されます。Nintendo Switch本体／SDカード...
# 60  To delete an Autodance:\n• Highlight the Just ...
#
#                                                 title  score_title
# 70   Healing injured operatives in Watch Dogs: Legion     0.246113
# 8    Keeping your Stadia save files for Ubisoft games     0.241367
# 19  Error message "A Ubisoft service is not availa...     0.196130
# 4   Decommissioning of online services for older U...     0.188718
# 57  Upgrading the Jackdaw in Assassin's Creed 4: B...     0.167950
# ..                                                ...          ...
# 90    Customising your appearance in Roller Champions    -0.032813
# 25                               For Honor Lore Recap    -0.034314
# 30             Changing language options in Far Cry 6    -0.036219
# 48           『アサシン クリード オデッセイ クラウドバージョン』セーブデータの保存について    -0.047222
# 60      Deleting Autodance videos in Just Dance games    -0.047392
#
# [100 rows x 3 columns]

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

knn_title = NearestNeighbors(n_neighbors=5, metric="cosine")
data = faq_articles_df["title_embedding"].values
data = np.vstack(data)
knn_title.fit(data)
# Out:
# NearestNeighbors(metric='cosine')

# %%
knn_content = NearestNeighbors(n_neighbors=5, metric="cosine")
data = faq_articles_df["content_embedding"].values
data = np.vstack(data)
knn_content.fit(data)
# Out:
# NearestNeighbors(metric='cosine')

# %%
knn_content_and_title = NearestNeighbors(n_neighbors=5, metric="cosine")
def row_mean(row):
    data = np.vstack((row["content_embedding"], row["title_embedding"]))
    return np.average(data, axis=0, weights=[1./5, 4./5])

data = faq_articles_df.progress_apply(row_mean, axis=1).values
data = np.vstack(data)
print(data.shape, data)
knn_content_and_title.fit(data)
# Out:
# 100%|██████████| 99/99 [00:00<00:00, 9857.70it/s]
# (99, 1024) [[ 0.70666069  0.01596309 -0.03587186 ...  0.02388256  0.0124868
#   -0.0896798 ]
#  [-0.05860371 -0.28635466  0.3071129  ... -0.07745139  0.38517178
#    0.2565737 ]
#  [-0.64907342  0.29745751  0.41481947 ... -0.42120284  0.15131914
#    0.19292997]
#  ...
#  [ 0.33056883 -0.54828329 -0.26837288 ... -0.09260171  0.80024089
#   -0.80291674]
#  [ 0.24524291  0.0338645  -0.09764073 ...  0.88006246  0.20052549
#    0.04589768]
#  [ 0.50445642  0.30209381  0.37284029 ... -0.27244188 -0.50273023
#    0.03406248]]
# NearestNeighbors(metric='cosine')

# %%
question_test = questions_df.iloc[4]
print(question_test)
distances_title, indices_title = knn_content_and_title.kneighbors(question_test["embedding"].reshape(1, -1), n_neighbors=20)
print("Distances:", distances_title)
print(faq_articles_df.iloc[indices_title[0]])
# Out:
# question     How to report a toxic playing behavior in Mari...
# embedding    [0.3089377, -0.56294197, 0.59237, 0.36797246, ...
# Name: 4, dtype: object
# Distances: [[0.6288601  0.68315991 0.71372585 0.73034581 0.74897224 0.76880563
#   0.77773899 0.77875956 0.78872011 0.81164458 0.82560202 0.83098521
#   0.83126708 0.83889213 0.84033573 0.84306354 0.84382378 0.84564189
#   0.84878564 0.85453432]]
#     articleID                                              title  \
# 14      64374  Accessing Challenges in Mario + Rabbids Kingdo...
# 55      64832         Configuring sound levels in Rabbids Coding
# 63      64847  Troubleshooting performance issues in Rabbids ...
# 66      62974  Locating in-game content for Mario + Rabbids K...
# 5       99331                   Reporting a bug in Ubisoft games
# 52     104647                    Cross-progression in Trackmania
# 13     103219  Code of Conduct for Mario + Rabbids Sparks of ...
# 51      76017                 Activating Deep Ocean in Anno 2070
# 16      80983                        Cross-play in Trials Rising
# 78      61393                  Looking around in Silent Hunter 5
# 60      77221      Deleting Autodance videos in Just Dance games
# 7      102641   Niflheim currencies in Assassin's Creed Valhalla
# 22      66168                              Crafting in Far Cry 5
# 38      61881       Configuring sound levels in Far Cry New Dawn
# 23      99148          Error Code Bookworm-BE8A522E in Far Cry 6
# 54      79352  Silvers and Helix Credits in Assassin's Creed ...
# 37      61584                    Hiding games in Ubisoft Connect
# 92     102629  Unlocking outfits in Niflheim for Assassin's C...
# 59      99744               Language options in Monopoly Madness
# 84      96205   Error code Boring-Pastrami in Watch Dogs: Legion
#
#                                          html_content  \
# 14  You can find two types of Challenges in Mario ...
# 55  In Rabbids Coding you can adjust the volume fo...
# 63  Rabbids Coding has been optimised to run as fl...
# 66  Most in-game content for Mario + Rabbids Kingd...
# 5   We encourage you to report issues to in order ...
# 52  Trackmania supports automatic cross-progressio...
# 13  At Ubisoft we are committed to providing an in...
# 51  To unlock the Deep Ocean content for Anno 2070...
# 16  Cross-play is not available in Trials Rising.\...
# 78  You can look around by selecting the right mou...
# 60  To delete an Autodance:\n• Highlight the Just ...
# 7   The Forgotten Saga introduces a range of resou...
# 22  Many useful items can be crafted by players th...
# 38  To set your preferred levels for the master vo...
# 23  This message occurs when there has been an iss...
# 54  There are two types of currency in Assassin's ...
# 37  The Games tab in Ubisoft Connect PC shows the ...
# 92  In Niflheim your gear works slightly different...
# 59  Below is a list of the supported languages for...
# 84  This error indicates that you have been unable...
#
#                                                   URL  \
# 14  https://www.ubisoft.com/help/game/article/titl...
# 55  https://www.ubisoft.com/help/game/article/titl...
# 63  https://www.ubisoft.com/help/game/article/titl...
# 66  https://www.ubisoft.com/help/game/article/titl...
# 5   https://www.ubisoft.com/help/game/article/titl...
# 52  https://www.ubisoft.com/help/game/article/titl...
# 13  https://www.ubisoft.com/help/game/article/titl...
# 51  https://www.ubisoft.com/help/game/article/titl...
# 16  https://www.ubisoft.com/help/game/article/titl...
# 78  https://www.ubisoft.com/help/game/article/titl...
# 60  https://www.ubisoft.com/help/game/article/titl...
# 7   https://www.ubisoft.com/help/game/article/titl...
# 22  https://www.ubisoft.com/help/game/article/titl...
# 38  https://www.ubisoft.com/help/game/article/titl...
# 23  https://www.ubisoft.com/help/game/article/titl...
# 54  https://www.ubisoft.com/help/game/article/titl...
# 37  https://www.ubisoft.com/help/game/article/titl...
# 92  https://www.ubisoft.com/help/game/article/titl...
# 59  https://www.ubisoft.com/help/game/article/titl...
# 84  https://www.ubisoft.com/help/game/article/titl...
#
#                                     content_embedding  \
# 14  [0.0008249419, -0.056534853, -0.11129209, 0.11...
# 55  [-0.11503884, 0.21651442, 0.19375141, 0.075595...
# 63  [-0.010796865, 0.078860275, 0.10509981, 0.0178...
# 66  [-0.031663273, 0.008023935, 0.07475223, 0.2221...
# 5   [0.09498133, 0.0034531322, 0.08224137, -0.0043...
# 52  [-0.05205415, -0.06505746, -0.0068076123, 0.40...
# 13  [-0.059636913, 0.03799423, 0.0050221267, 0.058...
# 51  [0.04584624, 0.110889815, 0.07169634, 0.138745...
# 16  [-0.22605519, -0.18709524, 0.49284935, 0.15832...
# 78  [-0.24603803, 0.050513748, 0.10863635, 0.25326...
# 60  [0.091678746, -0.1262877, 0.28734145, 0.142698...
# 7   [-0.13628693, -0.05621644, -0.012412937, 0.117...
# 22  [0.08924838, -0.035905015, 0.076295264, 0.2513...
# 38  [-0.080391474, 0.060629442, 0.00321906, 0.2594...
# 23  [-0.3776543, 0.39978567, -0.36560646, 0.164456...
# 54  [-0.12559907, 0.008432792, 0.0062309983, -0.06...
# 37  [-0.010245913, -0.122563645, 0.10449306, 0.081...
# 92  [-0.03863505, 0.08203185, -0.0014017419, 0.177...
# 59  [0.108712554, 0.25551328, 0.0896761, 0.0432025...
# 84  [0.2661262, 0.06917664, -0.21142323, 0.2265453...
#
#                                       title_embedding
# 14  [0.31464761, 0.14129125, -0.16736302, 0.355992...
# 55  [-0.1449148, -0.09624497, -0.24229339, 0.28270...
# 63  [-0.23021656, -0.5595575, 0.072194576, -0.1235...
# 66  [0.10977676, 0.72859675, 0.08919186, 0.2744479...
# 5   [-0.116135, -0.12877949, 0.5553872, -0.2059322...
# 52  [0.8763002, -1.0564008, -0.18275064, 1.1159267...
# 13  [0.18821344, 0.43011692, -0.12149848, -0.42576...
# 51  [-0.07707132, 0.043596275, -0.24173483, 0.4738...
# 16  [0.04993638, -0.79988843, 0.96047425, 0.362585...
# 78  [0.6873581, -0.7512912, 0.098651506, 0.5818709...
# 60  [0.5886789, -0.13885912, -0.07875597, 0.256730...
# 7   [0.114032425, 0.31456804, 0.2506771, 0.5186534...
# 22  [0.76635945, -0.626244, 0.43655363, 0.5120746,...
# 38  [0.119343854, 0.16978657, 0.4122217, 0.0042715...
# 23  [1.2065516, -0.18027918, 0.37085983, 0.1296198...
# 54  [0.10796906, -0.25534195, 0.25199237, -0.02296...
# 37  [-0.3278709, -0.010230355, 0.67054003, -0.1387...
# 92  [0.09852401, 0.10826499, 0.22300375, 0.0657548...
# 59  [0.21280377, 0.25210598, -0.21008503, 1.000076...
# 84  [0.8841645, -0.05504475, -0.072264485, -3.6460...

# %%
question_test = questions_df.iloc[0]
print(question_test)
distances_title, indices_title = knn_title.kneighbors(question_test["embedding"].reshape(1, -1), n_neighbors=20)
print("Distances:", distances_title)
print(faq_articles_df.iloc[indices_title[0]])
# Out:
# question                      How to make an explosive in FC5?
# embedding    [-0.49198765, -0.3451201, 0.43429187, -0.08201...
# Name: 0, dtype: object
# Distances: [[0.7652691  0.7693465  0.77511686 0.8015623  0.80417955 0.8079766
#   0.81531423 0.8159057  0.819003   0.82034844 0.82349557 0.82726014
#   0.82995915 0.8345226  0.83769727 0.8382895  0.83904624 0.8414052
#   0.8468493  0.849199  ]]
#     articleID                                             title  \
# 59      99744              Language options in Monopoly Madness
# 52     104647                   Cross-progression in Trackmania
# 37      61584                   Hiding games in Ubisoft Connect
# 30      98998            Changing language options in Far Cry 6
# 81      99058       Cross-platform content sharing in Far Cry 6
# 90     101948   Customising your appearance in Roller Champions
# 60      77221     Deleting Autodance videos in Just Dance games
# 16      80983                       Cross-play in Trials Rising
# 78      61393                 Looking around in Silent Hunter 5
# 38      61881      Configuring sound levels in Far Cry New Dawn
# 50      99039          Purchasing Resolver weapons in Far Cry 6
# 91      99045                     Using Photo Mode in Far Cry 6
# 51      76017                Activating Deep Ocean in Anno 2070
# 28      61900                Button mapping in Far Cry New Dawn
# 22      66168                             Crafting in Far Cry 5
# 5       99331                  Reporting a bug in Ubisoft games
# 55      64832        Configuring sound levels in Rabbids Coding
# 23      99148         Error Code Bookworm-BE8A522E in Far Cry 6
# 7      102641  Niflheim currencies in Assassin's Creed Valhalla
# 29      97507                Language options in the Rocksmith+
#
#                                          html_content  \
# 59  Below is a list of the supported languages for...
# 52  Trackmania supports automatic cross-progressio...
# 37  The Games tab in Ubisoft Connect PC shows the ...
# 30  In Far Cry 6 you can change the language for t...
# 81  If you play Far Cry 6 on multiple platforms, p...
# 90  In Roller Champions, you can customize your av...
# 60  To delete an Autodance:\n• Highlight the Just ...
# 16  Cross-play is not available in Trials Rising.\...
# 78  You can look around by selecting the right mou...
# 38  To set your preferred levels for the master vo...
# 50  Resolver weapons can be purchased from Juan's ...
# 91  To use photo mode:\n•  Open the in-game menu.\...
# 51  To unlock the Deep Ocean content for Anno 2070...
# 28  When using a controller, you have the ability ...
# 22  Many useful items can be crafted by players th...
# 5   We encourage you to report issues to in order ...
# 55  In Rabbids Coding you can adjust the volume fo...
# 23  This message occurs when there has been an iss...
# 7   The Forgotten Saga introduces a range of resou...
# 29  Below is a list of the supported languages for...
#
#                                                   URL  \
# 59  https://www.ubisoft.com/help/game/article/titl...
# 52  https://www.ubisoft.com/help/game/article/titl...
# 37  https://www.ubisoft.com/help/game/article/titl...
# 30  https://www.ubisoft.com/help/game/article/titl...
# 81  https://www.ubisoft.com/help/game/article/titl...
# 90  https://www.ubisoft.com/help/game/article/titl...
# 60  https://www.ubisoft.com/help/game/article/titl...
# 16  https://www.ubisoft.com/help/game/article/titl...
# 78  https://www.ubisoft.com/help/game/article/titl...
# 38  https://www.ubisoft.com/help/game/article/titl...
# 50  https://www.ubisoft.com/help/game/article/titl...
# 91  https://www.ubisoft.com/help/game/article/titl...
# 51  https://www.ubisoft.com/help/game/article/titl...
# 28  https://www.ubisoft.com/help/game/article/titl...
# 22  https://www.ubisoft.com/help/game/article/titl...
# 5   https://www.ubisoft.com/help/game/article/titl...
# 55  https://www.ubisoft.com/help/game/article/titl...
# 23  https://www.ubisoft.com/help/game/article/titl...
# 7   https://www.ubisoft.com/help/game/article/titl...
# 29  https://www.ubisoft.com/help/game/article/titl...
#
#                                     content_embedding  \
# 59  [0.108712554, 0.25551328, 0.0896761, 0.0432025...
# 52  [-0.05205415, -0.06505746, -0.0068076123, 0.40...
# 37  [-0.010245913, -0.122563645, 0.10449306, 0.081...
# 30  [0.23624846, -0.027841777, 0.089254886, 0.0676...
# 81  [-0.13515452, 0.18478008, 0.13815951, 0.128356...
# 90  [0.015287963, 0.11579727, -0.047696665, -0.198...
# 60  [0.091678746, -0.1262877, 0.28734145, 0.142698...
# 16  [-0.22605519, -0.18709524, 0.49284935, 0.15832...
# 78  [-0.24603803, 0.050513748, 0.10863635, 0.25326...
# 38  [-0.080391474, 0.060629442, 0.00321906, 0.2594...
# 50  [0.017152492, -0.07941991, -0.040297218, 0.364...
# 91  [-0.28546786, -0.064931326, -0.1905155, 0.1454...
# 51  [0.04584624, 0.110889815, 0.07169634, 0.138745...
# 28  [0.027701069, -0.15194961, 0.04873604, 0.13889...
# 22  [0.08924838, -0.035905015, 0.076295264, 0.2513...
# 5   [0.09498133, 0.0034531322, 0.08224137, -0.0043...
# 55  [-0.11503884, 0.21651442, 0.19375141, 0.075595...
# 23  [-0.3776543, 0.39978567, -0.36560646, 0.164456...
# 7   [-0.13628693, -0.05621644, -0.012412937, 0.117...
# 29  [-0.24329571, 0.1879898, -0.07167597, 0.043553...
#
#                                       title_embedding
# 59  [0.21280377, 0.25210598, -0.21008503, 1.000076...
# 52  [0.8763002, -1.0564008, -0.18275064, 1.1159267...
# 37  [-0.3278709, -0.010230355, 0.67054003, -0.1387...
# 30  [1.0522318, 0.3840281, 0.14205652, 0.3485251, ...
# 81  [0.6532812, -0.08523451, 0.5871426, 0.507796, ...
# 90  [0.5149235, -0.03582926, 0.13830392, -0.133823...
# 60  [0.5886789, -0.13885912, -0.07875597, 0.256730...
# 16  [0.04993638, -0.79988843, 0.96047425, 0.362585...
# 78  [0.6873581, -0.7512912, 0.098651506, 0.5818709...
# 38  [0.119343854, 0.16978657, 0.4122217, 0.0042715...
# 50  [0.78992695, -0.09628355, 0.33250394, 0.387862...
# 91  [0.6436884, -0.36747193, -0.21272728, 0.039008...
# 51  [-0.07707132, 0.043596275, -0.24173483, 0.4738...
# 28  [-0.062338192, -0.23353349, 0.36366042, -0.222...
# 22  [0.76635945, -0.626244, 0.43655363, 0.5120746,...
# 5   [-0.116135, -0.12877949, 0.5553872, -0.2059322...
# 55  [-0.1449148, -0.09624497, -0.24229339, 0.28270...
# 23  [1.2065516, -0.18027918, 0.37085983, 0.1296198...
# 7   [0.114032425, 0.31456804, 0.2506771, 0.5186534...
# 29  [0.53168, -0.20371862, 0.35589528, 0.512113, -...

# %%
distances_title, indices_title = knn_content.kneighbors(question_test["embedding"].reshape(1, -1), n_neighbors=20)
print("Distances:", distances_title)
print(faq_articles_df.iloc[indices_title[0]])
# Out:
# Distances: [[0.7254748  0.7410608  0.74405205 0.7606025  0.76504713 0.7806391
#   0.78327376 0.8004626  0.8050662  0.8061143  0.8147876  0.8157264
#   0.8247873  0.8261517  0.82665867 0.8341482  0.8348928  0.8367113
#   0.83753014 0.8413661 ]]
#     articleID                                              title  \
# 53      97180              Manually updating older Ubisoft games
# 99      60487        Online Multiplayer Settings in Watch Dogs 2
# 92     102629  Unlocking outfits in Niflheim for Assassin's C...
# 11      65295  White circles on the ground in Discovery Tour:...
# 44      62780  Locating the quest "Righting a Wrong" (Lost Ta...
# 54      79352  Silvers and Helix Credits in Assassin's Creed ...
# 38      61881       Configuring sound levels in Far Cry New Dawn
# 35     101322        Code of Conduct for Trivial Pursuit Live! 2
# 60      77221      Deleting Autodance videos in Just Dance games
# 76      60916            Contents of the Anno 1800 Season 1 Pass
# 9       62697          Location of Secrets of the First Pyramids
# 85      96704  Redeeming additional content for Assassin's Cr...
# 1       97885          Linking your YouTube and Ubisoft accounts
# 20     101379     Forwarding ports for Assassin's Creed Valhalla
# 43      65717  Accessing the quest Test of Judgment in Assass...
# 27     100657               Information about Ubisoft gift cards
# 88      65813              Corsair RGB Light Issues in Far Cry 5
# 72      94374  Troubleshooting connectivity issues in Immorta...
# 69      60947  Ubisoft games failing to launch on the Epic Ga...
# 81      99058        Cross-platform content sharing in Far Cry 6
#
#                                          html_content  \
# 53  While many of our older games can be found on ...
# 99  Watch Dogs 2 allows you to decide how much of ...
# 92  In Niflheim your gear works slightly different...
# 11  Some objects or non-player characters (NPC) wi...
# 44  The One Really, Really Bad Day quest chain of ...
# 54  There are two types of currency in Assassin's ...
# 38  To set your preferred levels for the master vo...
# 35  At Ubisoft we are committed to providing an in...
# 60  To delete an Autodance:\n• Highlight the Just ...
# 76  The Season 1 Pass will offer access to additio...
# 9   To unlock the Secrets of the First Pyramids qu...
# 85  To redeem additional content in Assassin's Cre...
# 1   To link your Ubisoft account to your YouTube a...
# 20  If you are experiencing connectivity issues in...
# 43  The Divine Intervention quest chain of Lost Ta...
# 27  Ubisoft Gift Cards allow you to gift Wallet cr...
# 88  In order to have your Corsair hardware properl...
# 72  Before diving into the thick of the troublesho...
# 69  If you are unable to start your game through t...
# 81  If you play Far Cry 6 on multiple platforms, p...
#
#                                                   URL  \
# 53  https://www.ubisoft.com/help/game/article/titl...
# 99  https://www.ubisoft.com/help/game/article/titl...
# 92  https://www.ubisoft.com/help/game/article/titl...
# 11  https://www.ubisoft.com/help/game/article/titl...
# 44  https://www.ubisoft.com/help/game/article/titl...
# 54  https://www.ubisoft.com/help/game/article/titl...
# 38  https://www.ubisoft.com/help/game/article/titl...
# 35  https://www.ubisoft.com/help/game/article/titl...
# 60  https://www.ubisoft.com/help/game/article/titl...
# 76  https://www.ubisoft.com/help/game/article/titl...
# 9   https://www.ubisoft.com/help/game/article/titl...
# 85  https://www.ubisoft.com/help/game/article/titl...
# 1   https://www.ubisoft.com/help/game/article/titl...
# 20  https://www.ubisoft.com/help/game/article/titl...
# 43  https://www.ubisoft.com/help/game/article/titl...
# 27  https://www.ubisoft.com/help/game/article/titl...
# 88  https://www.ubisoft.com/help/game/article/titl...
# 72  https://www.ubisoft.com/help/game/article/titl...
# 69  https://www.ubisoft.com/help/game/article/titl...
# 81  https://www.ubisoft.com/help/game/article/titl...
#
#                                     content_embedding  \
# 53  [-0.013282949, 0.026677895, -0.026100686, 0.18...
# 99  [0.006211248, -0.07747794, 0.1278508, 0.024992...
# 92  [-0.03863505, 0.08203185, -0.0014017419, 0.177...
# 11  [0.022707414, 0.09798387, -0.016946716, 0.4488...
# 44  [-0.16341056, -0.10149612, 0.1829643, 0.176217...
# 54  [-0.12559907, 0.008432792, 0.0062309983, -0.06...
# 38  [-0.080391474, 0.060629442, 0.00321906, 0.2594...
# 35  [-0.21884197, -0.04754034, 0.10292068, 0.18941...
# 60  [0.091678746, -0.1262877, 0.28734145, 0.142698...
# 76  [0.15875122, 0.13678287, -0.08821658, -0.00731...
# 9   [0.13154113, 0.26379558, 0.052521806, 0.234405...
# 85  [0.03552606, -0.023516404, 0.10045315, 0.22492...
# 1   [-0.21595939, 0.17474523, 0.01717826, -0.21959...
# 20  [0.0190462, 0.13525525, 0.049104735, 0.1745009...
# 43  [0.061524924, -0.09944737, 0.030318605, 0.0384...
# 27  [-0.11164871, 0.21616206, 0.24765389, -0.01032...
# 88  [0.071893275, -0.05020137, 0.2945414, 0.010496...
# 72  [0.06962334, -0.017211774, 0.114738464, -0.077...
# 69  [-0.17022984, -0.14356336, 0.27633828, -0.0881...
# 81  [-0.13515452, 0.18478008, 0.13815951, 0.128356...
#
#                                       title_embedding
# 53  [-0.44659624, 0.58111256, -0.118158236, 0.2031...
# 99  [0.6290177, 0.39698675, 0.43408766, 0.24859044...
# 92  [0.09852401, 0.10826499, 0.22300375, 0.0657548...
# 11  [0.2802138, -0.8341044, -0.324023, 0.39599916,...
# 44  [-0.35071072, -0.0717292, 0.29145733, 0.071170...
# 54  [0.10796906, -0.25534195, 0.25199237, -0.02296...
# 38  [0.119343854, 0.16978657, 0.4122217, 0.0042715...
# 35  [-0.17410773, 0.1745614, 0.13363919, 0.1751019...
# 60  [0.5886789, -0.13885912, -0.07875597, 0.256730...
# 76  [0.5711828, -0.24500126, 0.13961232, -0.266707...
# 9   [0.22092393, 0.45464182, 0.0027056423, -0.3598...
# 85  [0.16290922, -0.1452094, -0.09597739, 0.17828,...
# 1   [-0.019264793, -0.40162963, 0.37959656, -1.398...
# 20  [-0.087340295, 0.5438638, 0.17426187, -0.15990...
# 43  [-0.0730781, -0.37463197, 0.19815068, 0.524882...
# 27  [-0.66917855, 0.73757714, 0.40448803, -0.33744...
# 88  [0.5373038, -0.21414992, 0.30128926, 0.1533751...
# 72  [-0.31908122, -0.8197643, 0.02976083, 0.663657...
# 69  [0.21458074, -0.16492194, 0.26686466, 0.108949...
# 81  [0.6532812, -0.08523451, 0.5871426, 0.507796, ...

# %% [markdown]
# # Pre-trained model based

# %%
from transformers import AutoTokenizer, AutoModel

device = "cuda" if torch.cuda.is_available else "cpu"

model_name = "facebook/xlm-v-base" #"xlm-roberta-base"  # or any other suitable pre-trained model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/18.2M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/61.4M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.12G [00:00<?, ?B/s]
# Some weights of XLMRobertaModel were not initialized from the model checkpoint at facebook/xlm-v-base and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def get_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling
    return embeddings.cpu().detach().numpy()

faq_articles_df["content_embedding"] = faq_articles_df["html_content"].progress_apply(get_embeddings)
faq_articles_df.dropna(subset=["content_embedding"], inplace=True)
faq_articles_df["title_embedding"] = faq_articles_df["title"].progress_apply(get_embeddings)
faq_articles_df.dropna(subset=["title_embedding"], inplace=True)
questions_df["embedding"] = questions_df["question"].progress_apply(get_embeddings)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
faq_articles_df["title_content"] = "title: " + faq_articles_df["title"] + "\n content: " + faq_articles_df["html_content"]
faq_articles_df["title_content_embedding"] = faq_articles_df["title_content"].progress_apply(get_embeddings)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

knn_title = NearestNeighbors(n_neighbors=5, metric="cosine")
data = faq_articles_df["title_embedding"].values
data = np.vstack(data)
knn_title.fit(data)

knn_content = NearestNeighbors(n_neighbors=5, metric="cosine")
data = faq_articles_df["content_embedding"].values
data = np.vstack(data)
knn_content.fit(data)

knn_titlecontent = NearestNeighbors(n_neighbors=1, metric="cosine")
data = faq_articles_df["title_content_embedding"].values
data = np.vstack(data)
print(data)
knn_titlecontent.fit(data)
# Out:
# [[ 0.00024993  0.005599    0.01671557 ...  0.02056915 -0.00028062
#    0.1087667 ]
#  [ 0.02159384  0.01569649  0.02169064 ...  0.12161361 -0.02437468
#    0.08214884]
#  [ 0.02215911  0.00654834  0.00385957 ...  0.07124063  0.01232011
#    0.12010536]
#  ...
#  [-0.02619703 -0.01498317  0.01656552 ...  0.07921132  0.0367736
#    0.06971673]
#  [ 0.0090782   0.02640423 -0.00738526 ...  0.1068259   0.0082129
#    0.12073851]
#  [ 0.02965323  0.00925691  0.00635692 ...  0.07847287  0.00447676
#    0.08610021]]
# NearestNeighbors(metric='cosine', n_neighbors=1)

# %%
question_test = questions_df.iloc[0]
print(question_test.question)
distances_title, indices_title = knn_titlecontent.kneighbors(question_test["embedding"].reshape(1, -1), n_neighbors=1)
print("Distances:", distances_title)

def display(row):
    print("==========================")
    print("title_content:", row["title_content"])
    print("==========================\n")

faq_articles_df.iloc[indices_title[0]].apply(display, axis=1)
print()
# Out:
# How to make an explosive in FC5?
# Distances: [[0.0064888]]
# ==========================
# title_content: title: Error Code Bookworm-BE8A522E in Far Cry 6
#  contentThis message occurs when there has been an issue accepting a co-op session invite from another player.
# You can resolve this by restarting the game.
# ==========================

# %%
def similarity_search(question:str):
    _, indices_title = knn_titlecontent.kneighbors(question_test["embedding"].reshape(1, -1), n_neighbors=1)
    return faq_articles_df.iloc[indices_title[0][0]]["articleID"]
questions_df["article_id"] = questions_df["question"].progress_apply(similarity_search)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
questions_df
# Out:
#                                              question  \
# 0                    How to make an explosive in FC5?
# 1   Are there any news on when AC Jade will be ava...
# 2   Is it possible to continue my progression if I...
# 3   Will Starlink run on a GPU with 2GB RAM? Is th...
# 4   How to report a toxic playing behavior in Mari...
# 5        I have an error BE8A522E. What does it mean?
# 6   I wanted to play HoMM IV after a long break, b...
# 7                     How to sign up for Just Dance+?
# 8   I can't find the Discovery Tour in ACV despite...
# 9   Comment puis-je informer les développeurs d'Ub...
# 10  Est-il possible d'obtenir un Alpha Pack gratui...
# 11  Quelle est la signification des anneaux blancs...
# 12  Comment résoudre le problème "Service Ubisoft ...
# 13  Puis-je changer le nom de famille de mon compte ?
# 14  J'aimerais lancer le jeu dans une fenêtre. Est...
# 15  comment restaurer les pièces perdues dans la "...
# 16      J'obtiens l'erreur 17008. Que dois-je faire ?
# 17               Quelle est l'histoire du jeu du FH ?
# 18  Y a-t-il des défis coopératifs dans Mario + La...
# 19  ¿Es posible jugar Trials Rising con un amigo e...
# 20  ¿Puedo comprar algunos créditos de billetera a...
# 21  ¿Cómo llegar a la campaña de Jack The Ripper e...
# 22  ¿Cuál es la diferencia entre las ediciones "de...
# 23  ¿Cómo desbloquear la misión "Secretos de las p...
# 24  No se puede conectar a los servidores de Ubiso...
# 25  ¿Es posible asociar mis perfiles de Ubisoft y ...
# 26  ¿Es posible modificar la dificultad de Starlin...
# 27  ¿Dónde conseguir las recompensas "Ubi Connect"...
#
#                                             embedding  article_id
# 0   [[-0.01766024, 0.040068943, 0.011997369, 0.007...       99148
# 1   [[-0.042750146, 0.0049722022, 0.01994016, 0.01...       99148
# 2   [[-0.01710297, 0.02514645, 0.0048631486, -0.02...       99148
# 3   [[-0.027429102, -0.002572644, 0.040274885, 0.0...       99148
# 4   [[0.03184674, 0.011886748, 0.031098751, 0.0179...       99148
# 5   [[0.011777533, 0.05218943, 0.0007697771, -0.00...       99148
# 6   [[-0.013195799, -0.009787414, -0.009858473, -0...       99148
# 7   [[0.03481711, 0.041446667, 0.022202183, 0.0385...       99148
# 8   [[-0.03882204, 0.011960899, -0.0033591096, 0.0...       99148
# 9   [[-0.015457971, 0.018980213, 0.027896011, 0.00...       99148
# 10  [[-0.034564234, 0.016238185, 0.04963123, 0.017...       99148
# 11  [[-0.03056914, -0.00460533, -0.002702534, -0.0...       99148
# 12  [[-0.005017838, 0.024642652, 0.013018873, 0.02...       99148
# 13  [[0.01389333, 0.021229977, -0.020682525, -0.01...       99148
# 14  [[0.0024445748, 0.01241931, 0.024756094, 0.003...       99148
# 15  [[-0.044083096, -0.0012845953, -0.011784798, -...       99148
# 16  [[-0.014014496, 0.043769166, 0.007659328, -0.0...       99148
# 17  [[0.016434686, 0.030465437, 0.029694678, -0.00...       99148
# 18  [[-0.0027435983, -0.027986955, 0.009204505, -0...       99148
# 19  [[0.01626273, -0.01863288, 0.01768445, -0.0096...       99148
# 20  [[-0.014305266, -0.014750105, 0.0015951069, -0...       99148
# 21  [[0.029463334, -0.024647359, 0.015434386, -0.0...       99148
# 22  [[0.014303654, -0.01705133, 0.020324592, 0.017...       99148
# 23  [[0.007008967, -0.023776483, 0.016103987, 0.01...       99148
# 24  [[0.0020844443, -0.0135245975, 0.023750192, -0...       99148
# 25  [[0.015497516, -0.0071763587, 0.0054949955, -0...       99148
# 26  [[0.016930208, -0.04520118, 0.00911815, -0.027...       99148
# 27  [[0.032783642, -0.00016071628, 0.017329456, 0....       99148

# %% [markdown]
# ### Manual Cosine method

# %%
# m = torch.nn.CosineSimilarity(dim=1)
from sklearn.metrics.pairwise import cosine_similarity


def similarity_search(question_embedding):
    data = faq_articles_df[["title_content", "title_embedding", "content_embedding", "title_content_embedding", "articleID"]].copy(deep=True)
    # data["score"] = data["title_embedding"].apply(lambda emb: m(torch.tensor(question_embedding), torch.tensor(emb)).item())
    # data["score"] = data["title_embedding"].apply(lambda emb: cosine_similarity(question_embedding, emb)[0,0])
    data["score"] = data["title_content_embedding"].apply(lambda emb: torch.cdist(torch.tensor(question_embedding), torch.tensor(emb)).item())
    data.sort_values(by=["score"], inplace=True, ascending=True)
    print(data)
    return data.iloc[0:5]
id=10
print("question:", questions_df.iloc[id].question)
# print("question:", faq_articles_df.iloc[id].title)
# result = faq_articles_df.iloc[id:id+1]["title_embedding"].progress_apply(similarity_search)
result = questions_df.iloc[id:id+1]["embedding"].progress_apply(similarity_search)
print(result.iloc[0].title_content)
# Out:
# question: Est-il possible d'obtenir un Alpha Pack gratuitement dans R6S ?
#   0%|          | 0/1 [00:00<?, ?it/s]
#                                         title_content  \
# 9   title: Location of Secrets of the First Pyrami...
# 94  title: Ubisoft Store - Issue exchanging Ubisof...
# 39  title: Contents of Far Cry 3 Classic Edition (...
# 16  title: Cross-play in Trials Rising\n content: ...
# 43  title: Accessing the quest Test of Judgment in...
# ..                                                ...
# 58  title: System requirements for Rocksmith+ (PC)...
# 74  title: System requirements for Assassin's Cree...
# 32  title: System requirements for Watch Dogs 2\n ...
# 62  title: Troubleshooting technical issues on Pla...
# 77  title: System requirements for Assassin's Cree...
#
#                                       title_embedding  \
# 9   [[0.0005317729, -0.00161402, 0.008354791, -0.0...
# 94  [[0.0026955556, -0.016921623, 0.010726158, -0....
# 39  [[0.007894096, -0.009946631, 0.0016931917, 0.0...
# 16  [[0.0049432893, -0.0030729354, 0.006644571, 0....
# 43  [[0.0028395262, -0.0012925295, 0.007230701, 0....
# ..                                                ...
# 58  [[0.002194965, -4.150871e-05, 0.001561745, 0.0...
# 74  [[-6.539808e-05, -0.0054929624, 0.009246194, 0...
# 32  [[0.0044075404, -0.0008254276, 0.007742055, 0....
# 62  [[0.011068432, -0.003918273, 0.0017962551, 0.0...
# 77  [[0.003592771, -0.0024958407, 0.009895052, 0.0...
#
#                                     content_embedding  \
# 9   [[-0.00025560675, -0.0021749898, 0.008540729, ...
# 94  [[0.02048402, -0.006020185, 0.007355512, -0.01...
# 39  [[0.007900022, -0.007890009, 0.008018324, -0.0...
# 16  [[0.009219238, -0.0021132578, 0.010215249, -0....
# 43  [[0.0014431311, 0.0024218475, 0.007295832, -0....
# ..                                                ...
# 58  [[-0.0025341404, -0.0134061985, 0.0010257382, ...
# 74  [[0.00037280266, -0.012165014, 0.004029341, 0....
# 32  [[0.00036578812, -0.014886891, 0.0025425474, 0...
# 62  [[0.007419391, -0.012875392, 0.009672987, -0.0...
# 77  [[-0.00020860563, -0.009526696, 0.007238209, 0...
#
#                               title_content_embedding  articleID     score
# 9   [[0.00012807321, -0.0037403877, 0.009115293, -...      62697  0.267250
# 94  [[0.015543293, -0.011558376, 0.007972179, -0.0...     105862  0.274359
# 39  [[0.006902782, -0.009366788, 0.006917786, -0.0...      63679  0.292734
# 16  [[0.008735895, -0.007490802, 0.008715392, -0.0...      80983  0.297671
# 43  [[0.0019430165, 0.0009053814, 0.0071472344, -0...      65717  0.305626
# ..                                                ...        ...       ...
# 58  [[-0.0016091112, -0.013550936, 0.0017383719, 0...      97555  0.507632
# 74  [[-0.00022423673, -0.012681039, 0.004313059, 0...      78336  0.507904
# 32  [[0.00025062525, -0.015523955, 0.00305598, 0.0...      61087  0.531905
# 62  [[0.00771491, -0.013015146, 0.009779759, -0.01...      95486  0.538139
# 77  [[0.0016855816, -0.01049594, 0.008066669, 0.00...      75381  0.544414
#
# [100 rows x 6 columns]
# 9     title: Location of Secrets of the First Pyrami...
# 94    title: Ubisoft Store - Issue exchanging Ubisof...
# 39    title: Contents of Far Cry 3 Classic Edition (...
# 16    title: Cross-play in Trials Rising\n content: ...
# 43    title: Accessing the quest Test of Judgment in...
# Name: title_content, dtype: object

# %%
m = torch.nn.CosineSimilarity(dim=1)


def similarity_search(question_embedding):
    data = faq_articles_df[["title", "title_content_embedding", "articleID"]].copy(deep=True)
    data["score"] = data["title_content_embedding"].apply(lambda emb: m(torch.tensor(question_embedding), torch.tensor(emb)).item())
    data.sort_values(by=["score"], inplace=True, ascending=False)
    return data.iloc[0].articleID, data.iloc[0].title

questions_df["article_id", "article_title"] = questions_df["embedding"].progress_apply(similarity_search)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
questions_df
# Out:
#                                              question  \
# 0                    How to make an explosive in FC5?
# 1   Are there any news on when AC Jade will be ava...
# 2   Is it possible to continue my progression if I...
# 3   Will Starlink run on a GPU with 2GB RAM? Is th...
# 4   How to report a toxic playing behavior in Mari...
# 5        I have an error BE8A522E. What does it mean?
# 6   I wanted to play HoMM IV after a long break, b...
# 7                     How to sign up for Just Dance+?
# 8   I can't find the Discovery Tour in ACV despite...
# 9   Comment puis-je informer les développeurs d'Ub...
# 10  Est-il possible d'obtenir un Alpha Pack gratui...
# 11  Quelle est la signification des anneaux blancs...
# 12  Comment résoudre le problème "Service Ubisoft ...
# 13  Puis-je changer le nom de famille de mon compte ?
# 14  J'aimerais lancer le jeu dans une fenêtre. Est...
# 15  comment restaurer les pièces perdues dans la "...
# 16      J'obtiens l'erreur 17008. Que dois-je faire ?
# 17               Quelle est l'histoire du jeu du FH ?
# 18  Y a-t-il des défis coopératifs dans Mario + La...
# 19  ¿Es posible jugar Trials Rising con un amigo e...
# 20  ¿Puedo comprar algunos créditos de billetera a...
# 21  ¿Cómo llegar a la campaña de Jack The Ripper e...
# 22  ¿Cuál es la diferencia entre las ediciones "de...
# 23  ¿Cómo desbloquear la misión "Secretos de las p...
# 24  No se puede conectar a los servidores de Ubiso...
# 25  ¿Es posible asociar mis perfiles de Ubisoft y ...
# 26  ¿Es posible modificar la dificultad de Starlin...
# 27  ¿Dónde conseguir las recompensas "Ubi Connect"...
#
#                                             embedding  article_id  \
# 0   [[0.005815069, -0.0032068184, 0.009311468, 0.0...       62697
# 1   [[0.0056408206, -0.008635589, 0.0058236443, 0....      105862
# 2   [[0.004945445, 0.0048120166, 0.011660387, -0.0...      102641
# 3   [[0.0070026894, -0.0045886934, 0.012220346, -0...       99148
# 4   [[0.001433985, 0.002091226, 0.00673151, 0.0043...       60916
# 5   [[0.012558115, -0.0032170757, 0.00033806168, -...       99148
# 6   [[0.0006757137, -0.010852469, 0.009820812, -0....       61934
# 7   [[-0.0025944444, -0.0012060399, 0.009584829, -...       62697
# 8   [[0.0034633633, -0.010108132, 0.017663503, -0....       62780
# 9   [[0.014862637, -0.0033176357, 0.0042878105, -0...       62697
# 10  [[0.007889992, -0.006955366, 0.0073248893, -0....       80983
# 11  [[0.009394157, -0.0051570623, 0.012034353, 4.0...       62697
# 12  [[0.00038316593, -0.008594345, 0.0068919137, 0...      105862
# 13  [[0.006665246, -0.0030567807, 0.00910594, 0.00...       62697
# 14  [[0.009744064, -0.0012193114, 0.0020042374, -0...       99148
# 15  [[0.004049473, 0.00297382, 0.011401083, -0.005...      105862
# 16  [[0.0049603023, -0.0064682774, -0.0013358297, ...       64832
# 17  [[0.004711516, -0.0028084305, 0.009830938, 0.0...      105862
# 18  [[0.008405184, -0.008630462, 0.0054476517, 0.0...       62697
# 19  [[0.007432348, -0.0065622004, 0.006307061, 0.0...       62697
# 20  [[0.004484855, -0.013728148, -0.001411721, 0.0...      102641
# 21  [[0.001215504, -0.007866429, 0.0024058593, 0.0...       62697
# 22  [[0.0145820845, -0.013889209, 0.0110065965, -0...       65237
# 23  [[0.009772248, -0.0025453344, 0.001937243, -0....      105862
# 24  [[0.0050997348, -0.004874447, 0.003363244, 0.0...      105862
# 25  [[0.007983064, -0.011633449, -0.0015138148, 0....      105862
# 26  [[0.0045813145, 0.0019109133, 0.0070344475, 0....      102641
# 27  [[0.013463068, -0.0073528644, 0.0010020903, -0...      105862
#
#                           (article_id, article_title)
# 0   (62697, Location of Secrets of the First Pyram...
# 1   (105862, Ubisoft Store - Issue exchanging Ubis...
# 2   (102641, Niflheim currencies in Assassin's Cre...
# 3   (99148, Error Code Bookworm-BE8A522E in Far Cr...
# 4    (60916, Contents of the Anno 1800 Season 1 Pass)
# 5   (99148, Error Code Bookworm-BE8A522E in Far Cr...
# 6                           (61934, Equinox upgrades)
# 7   (62697, Location of Secrets of the First Pyram...
# 8   (62780, Locating the quest "Righting a Wrong" ...
# 9   (62697, Location of Secrets of the First Pyram...
# 10               (80983, Cross-play in Trials Rising)
# 11  (62697, Location of Secrets of the First Pyram...
# 12  (105862, Ubisoft Store - Issue exchanging Ubis...
# 13  (62697, Location of Secrets of the First Pyram...
# 14  (99148, Error Code Bookworm-BE8A522E in Far Cr...
# 15  (105862, Ubisoft Store - Issue exchanging Ubis...
# 16  (64832, Configuring sound levels in Rabbids Co...
# 17  (105862, Ubisoft Store - Issue exchanging Ubis...
# 18  (62697, Location of Secrets of the First Pyram...
# 19  (62697, Location of Secrets of the First Pyram...
# 20  (102641, Niflheim currencies in Assassin's Cre...
# 21  (62697, Location of Secrets of the First Pyram...
# 22  (65237, Language options in Assassin's Creed: ...
# 23  (105862, Ubisoft Store - Issue exchanging Ubis...
# 24  (105862, Ubisoft Store - Issue exchanging Ubis...
# 25  (105862, Ubisoft Store - Issue exchanging Ubis...
# 26  (102641, Niflheim currencies in Assassin's Cre...
# 27  (105862, Ubisoft Store - Issue exchanging Ubis...

# %%
questions_df.to_csv("./output.csv", columns=["question", "article_id"])

# %% [markdown]
# The result given by this method is very deceiving, unfortunately. I spent too much time trying to understand what is the issue with it and decided to stop after searching for 5h.
#
# I have tried different methods from my knowledge but haven't figured out a way to fix this. In the past I had the occasion to use this method successfully without any issue, but it seems that here, it doesn't work as expected.
